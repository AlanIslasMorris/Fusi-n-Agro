# %%
from IPython.display import display
from IPython.display import HTML
import IPython.core.display as di # Example: di.display_html('<h3>%s:</h3>' % str, raw=True)

# This line will hide code by default when the notebook is exported as HTML
di.display_html('<script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>', raw=True)

# This line will add a button to toggle visibility of code blocks, for use with the HTML export version
di.display_html('''<button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>''', raw=True)

# Se importan paquetes de análisis de datos- Proceso

import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

# Se importa base de plan de ventas fusión Agro 

BaseVentasFusionAgro = pd.read_csv("11.csv")

# Se importan categorías de producto, cultivo y cliente

Zona = pd.read_csv("Zona.csv")

Producto = pd.read_csv("Producto.csv")

Cultivo = pd.read_csv("Cultivo.csv")

Mesatrimestre = pd.read_csv("Mesatrimestre.csv")

# Se incluyen las categorías en la base

Ventas_zona = BaseVentasFusionAgro.merge(Zona, how='left', left_on='RM/ REIQ', right_on='RM/ REIQ_')

Ventas_zona_producto = Ventas_zona.merge(Producto, how='left', left_on='Producto_', right_on='Producto_')

Ventas_zona_producto_ = Ventas_zona_producto.merge(Mesatrimestre, how='left', left_on='Mes', right_on='Mes')

Ventas_zona_producto_cultivo_ = Ventas_zona_producto_.merge(Cultivo, how='left', left_on='Cultivo_', right_on='Cultivo', indicator = True)
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>
# <button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>

# %%
#Criterios para filtrar datos

Periodoconsiderado_2022 = Ventas_zona_producto_cultivo_['Periodo'] == 2022
Periodoconsiderado2021 = Ventas_zona_producto_cultivo_['Periodo'] == 2021
T1 = Ventas_zona_producto_cultivo_['Trimestre'] == "T1"
EmpresaconsideradaMéxico = Ventas_zona_producto_cultivo_ ['Empresa'] == "México"
EmpresaconsideradaNOesMéxico = Ventas_zona_producto_cultivo_ ['Empresa'] != "México"
AdmCat_Cito = Ventas_zona_producto_cultivo_['Administracion de la categoria'] == "1 Cito"
AdmCat_Suelo = Ventas_zona_producto_cultivo_['Administracion de la categoria'] == "2 Raiz/ suelo"
AdmCat_Bioest = Ventas_zona_producto_cultivo_['Administracion de la categoria'] == "3 Bioestimulante"
AdmCat_Coady = Ventas_zona_producto_cultivo_['Administracion de la categoria'] == "4 Coadyuvante"
H2 = Ventas_zona_producto_cultivo_['H1 o H2 o Resto'] == "H2"

# También es posible filtrar por zona p.ej.: ['Zona_Ranking'] == '02 Pacífico'
# En lugar de Pacífico las otras zonas son:
# '01 Norte', '08 Ecu,Col,EUA', '05 Zona 2','06 IqChem', '07 Zona 1', '03 Sureste', '04 Chile/Perú'
# Las otras empresas: 
# 'Intnl', 'CAC', 'IqChem', 'SUD'

# %%
# Plan 2022 corresponde al año 2022, también es posible seleccionar 2020 o 2021

Ventas_zona_producto_cultivo = Ventas_zona_producto_cultivo_

#Columnas auxiliares

Ventas_zona_producto_cultivo['Utilidad $M'] = Ventas_zona_producto_cultivo['Utilidad']/1000000

Ventas_zona_producto_cultivo['Utilidad/Utilidad_total (%)'] = Ventas_zona_producto_cultivo['Utilidad']*100/(Ventas_zona_producto_cultivo['Utilidad'].sum())

# La base de ventas fusión agro, se filtra por año y/o empresa y/o categoría
# Se usa la base que incluye categorías de cultivos, clientes y productos
# Se usan los criterios para filtrar datos listados previamente
# Se muestra sólo T1

Ventas_zona_producto_cultivo_T1 = Ventas_zona_producto_cultivo_[
    T1 ]

Ventas_zona_producto_cultivo_Mx_2022 = Ventas_zona_producto_cultivo_[
    EmpresaconsideradaMéxico &
    Periodoconsiderado_2022&
    T1]

Ventas_zona_producto_cultivo_noesMx_2022 = Ventas_zona_producto_cultivo_[
    EmpresaconsideradaNOesMéxico &
    Periodoconsiderado_2022&
    T1]

Ventas_zona_producto_cultivo_2021 = Ventas_zona_producto_cultivo_[
    Periodoconsiderado2021&
    T1]

Ventas_zona_producto_cultivo_2022 = Ventas_zona_producto_cultivo_[
    Periodoconsiderado_2022&
    T1]

Ventas_zona_producto_cultivo_Cito_2022 = Ventas_zona_producto_cultivo_[
    Periodoconsiderado_2022  &
    AdmCat_Cito&
    T1]
Ventas_zona_producto_cultivo_Suelo_2022 = Ventas_zona_producto_cultivo_[
    Periodoconsiderado_2022 &
    AdmCat_Suelo&
    T1]
Ventas_zona_producto_cultivo_Bioest_2022 = Ventas_zona_producto_cultivo_[
    Periodoconsiderado_2022 &
    AdmCat_Bioest&
    T1]
Ventas_zona_producto_cultivo_Coady_2022 = Ventas_zona_producto_cultivo_[
    Periodoconsiderado_2022 &
    AdmCat_Coady&
    T1]

# %% [markdown]
# # Análisis de Base de ventas Fusión Agro

# %% [markdown]
# # Utilidad ($M) Fusión Agro por zona y por año

# %%
UZA_ = Ventas_zona_producto_cultivo_T1.groupby(['Periodo','Zona_Ranking']).agg({'Utilidad $M': 'sum'})
UZA_df = pd.DataFrame(UZA_.unstack(level = 1))
UZA_df.plot.bar(stacked=True)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %%
UZA2 = Ventas_zona_producto_cultivo_T1.groupby(['Periodo']).agg({'Utilidad $M': 'sum'})
UZA2.style.format('${0:,.2f}').bar(color='lightgreen', vmin=0, subset=['Utilidad $M'])
# Out:
# <style  type="text/css" >
# #T_256b8_row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 63.6%, transparent 63.6%);
#         }#T_256b8_row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 83.1%, transparent 83.1%);
#         }#T_256b8_row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
#         }</style><table id="T_256b8_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Utilidad $M</th>    </tr>    <tr>        <th class="index_name level0" >Periodo</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_256b8_level0_row0" class="row_heading level0 row0" >2020</th>
#                         <td id="T_256b8_row0_col0" class="data row0 col0" >$47.00</td>
#             </tr>
#             <tr>
#                         <th id="T_256b8_level0_row1" class="row_heading level0 row1" >2021</th>
#                         <td id="T_256b8_row1_col0" class="data row1 col0" >$61.46</td>
#             </tr>
#             <tr>
#                         <th id="T_256b8_level0_row2" class="row_heading level0 row2" >2022</th>
#                         <td id="T_256b8_row2_col0" class="data row2 col0" >$73.95</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Utilidad ($M) Fusión Agro

# %%
print ('${:,.3f} M'.format(Ventas_zona_producto_cultivo_2022['Utilidad'].sum()/1000000) )
# Out:
# $73.946 M

# %% [markdown]
# # Crecimiento respecto al 2021

# %%
print ('{:,.2f} %'.format(
                            ((Ventas_zona_producto_cultivo_2022['Utilidad'].sum()/
                            Ventas_zona_producto_cultivo_2021['Utilidad'].sum())-1)*100
                        ))
# Out:
# 20.31 %

# %% [markdown]
#  # Desglose por zona y por categoría

# %%
RCZ = Ventas_zona_producto_cultivo_2022.groupby(['Administracion de la categoria','Zona_Ranking']).agg({'Utilidad $M': 'sum'}).reset_index()
RCZ_ = Ventas_zona_producto_cultivo_2022.groupby(['Administracion de la categoria','Zona_Ranking']).agg({'Utilidad $M': 'sum'})
RCZ_df = pd.DataFrame(RCZ_.unstack(level = 1))
RCZ_df.plot.bar(stacked=True)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %%
RCZ2 = Ventas_zona_producto_cultivo_2022.groupby(['Administracion de la categoria']).agg({'Utilidad $M': 'sum'})
RCZ2.head(20).style.format('${0:,.2f}').bar(color='lightgreen', vmin=0, subset=['Utilidad $M'])
# Out:
# <style  type="text/css" >
# #T_4bdd5_row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
#         }#T_4bdd5_row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 64.9%, transparent 64.9%);
#         }#T_4bdd5_row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 41.4%, transparent 41.4%);
#         }#T_4bdd5_row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 36.4%, transparent 36.4%);
#         }#T_4bdd5_row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 4.3%, transparent 4.3%);
#         }#T_4bdd5_row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 7.6%, transparent 7.6%);
#         }</style><table id="T_4bdd5_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Utilidad $M</th>    </tr>    <tr>        <th class="index_name level0" >Administracion de la categoria</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4bdd5_level0_row0" class="row_heading level0 row0" >1 Cito</th>
#                         <td id="T_4bdd5_row0_col0" class="data row0 col0" >$29.04</td>
#             </tr>
#             <tr>
#                         <th id="T_4bdd5_level0_row1" class="row_heading level0 row1" >2 Raiz/ suelo</th>
#                         <td id="T_4bdd5_row1_col0" class="data row1 col0" >$18.85</td>
#             </tr>
#             <tr>
#                         <th id="T_4bdd5_level0_row2" class="row_heading level0 row2" >3 Bioestimulante</th>
#                         <td id="T_4bdd5_row2_col0" class="data row2 col0" >$12.03</td>
#             </tr>
#             <tr>
#                         <th id="T_4bdd5_level0_row3" class="row_heading level0 row3" >4 Coadyuvante</th>
#                         <td id="T_4bdd5_row3_col0" class="data row3 col0" >$10.58</td>
#             </tr>
#             <tr>
#                         <th id="T_4bdd5_level0_row4" class="row_heading level0 row4" >5 GA</th>
#                         <td id="T_4bdd5_row4_col0" class="data row4 col0" >$1.24</td>
#             </tr>
#             <tr>
#                         <th id="T_4bdd5_level0_row5" class="row_heading level0 row5" >6 Nutrici�n</th>
#                         <td id="T_4bdd5_row5_col0" class="data row5 col0" >$2.20</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Análisis por categoría

# %% [markdown]
# # Cito, 2022

# %% [markdown]
# # Valor de Cito y lo que representa respecto a utilidad total

# %%
utilidadtotal2022 = Ventas_zona_producto_cultivo_2022['Utilidad'].sum()
utilidadcito2022 = Ventas_zona_producto_cultivo_Cito_2022['Utilidad'].sum()
utilidadcito2022/ utilidadtotal2022
print ('${:,.3f} M'.format(Ventas_zona_producto_cultivo_Cito_2022['Utilidad'].sum()/1000000) )
print ('{:,.1f} %'.format(utilidadcito2022*100/ utilidadtotal2022))
# Out:
# $29.044 M
# 39.3 %

# %%
ResumenporHorizonteyEmp = Ventas_zona_producto_cultivo_Cito_2022.groupby(['Zona_Ranking','Producto_']).agg({'Utilidad $M': 'sum'}).reset_index()
ResumenporHorizonteyEmp_ = Ventas_zona_producto_cultivo_Cito_2022.groupby(['Zona_Ranking','Producto_']).agg({'Utilidad $M': 'sum'})
ResumenporHorizonteyEmp_df = pd.DataFrame(ResumenporHorizonteyEmp_.unstack(level = 1))
ResumenporHorizonteyEmp_df.plot.bar(stacked=True)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %%
Ventas_RM_Cito_2022 = Ventas_zona_producto_cultivo_Cito_2022.groupby(['RM/ REIQ_Ranking']).agg({'Utilidad $M': 'sum'})
Ventas_RM_Cito_2022_sorted = Ventas_RM_Cito_2022.sort_values(by=['Utilidad $M'],ascending=False)
Ventas_RM_Cito_2022_sorted.head(10).style.format('${0:,.2f}').bar(color='lightgreen', vmin=0, subset=['Utilidad $M'])
# Out:
# <style  type="text/css" >
# #T_458d7_row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
#         }#T_458d7_row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 83.7%, transparent 83.7%);
#         }#T_458d7_row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 35.0%, transparent 35.0%);
#         }#T_458d7_row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 34.5%, transparent 34.5%);
#         }#T_458d7_row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 29.6%, transparent 29.6%);
#         }#T_458d7_row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 26.9%, transparent 26.9%);
#         }#T_458d7_row6_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 21.6%, transparent 21.6%);
#         }#T_458d7_row7_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 21.3%, transparent 21.3%);
#         }#T_458d7_row8_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 17.5%, transparent 17.5%);
#         }#T_458d7_row9_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 16.9%, transparent 16.9%);
#         }</style><table id="T_458d7_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Utilidad $M</th>    </tr>    <tr>        <th class="index_name level0" >RM/ REIQ_Ranking</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_458d7_level0_row0" class="row_heading level0 row0" >01 Ditecosa</th>
#                         <td id="T_458d7_row0_col0" class="data row0 col0" >$6.14</td>
#             </tr>
#             <tr>
#                         <th id="T_458d7_level0_row1" class="row_heading level0 row1" >10 Drokasa</th>
#                         <td id="T_458d7_row1_col0" class="data row1 col0" >$5.14</td>
#             </tr>
#             <tr>
#                         <th id="T_458d7_level0_row2" class="row_heading level0 row2" >02 JF</th>
#                         <td id="T_458d7_row2_col0" class="data row2 col0" >$2.15</td>
#             </tr>
#             <tr>
#                         <th id="T_458d7_level0_row3" class="row_heading level0 row3" >11 Empresas Melo</th>
#                         <td id="T_458d7_row3_col0" class="data row3 col0" >$2.12</td>
#             </tr>
#             <tr>
#                         <th id="T_458d7_level0_row4" class="row_heading level0 row4" >05 GT</th>
#                         <td id="T_458d7_row4_col0" class="data row4 col0" >$1.82</td>
#             </tr>
#             <tr>
#                         <th id="T_458d7_level0_row5" class="row_heading level0 row5" >03 Quinval</th>
#                         <td id="T_458d7_row5_col0" class="data row5 col0" >$1.65</td>
#             </tr>
#             <tr>
#                         <th id="T_458d7_level0_row6" class="row_heading level0 row6" >12 Propios</th>
#                         <td id="T_458d7_row6_col0" class="data row6 col0" >$1.32</td>
#             </tr>
#             <tr>
#                         <th id="T_458d7_level0_row7" class="row_heading level0 row7" >06 AACSA</th>
#                         <td id="T_458d7_row7_col0" class="data row7 col0" >$1.31</td>
#             </tr>
#             <tr>
#                         <th id="T_458d7_level0_row8" class="row_heading level0 row8" >16 Txao</th>
#                         <td id="T_458d7_row8_col0" class="data row8 col0" >$1.07</td>
#             </tr>
#             <tr>
#                         <th id="T_458d7_level0_row9" class="row_heading level0 row9" >15 Ciba</th>
#                         <td id="T_458d7_row9_col0" class="data row9 col0" >$1.03</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Raíz/ Suelo, 2022

# %% [markdown]
# # Valor de RaízSuelo y lo que representa respecto a utilidad total

# %%
utilidadtotal2022 = Ventas_zona_producto_cultivo_2022['Utilidad'].sum()
utilidadsuelo2022 = Ventas_zona_producto_cultivo_Suelo_2022['Utilidad'].sum()
print ('${:,.3f} M'.format(Ventas_zona_producto_cultivo_Suelo_2022['Utilidad'].sum()/1000000) )
print ('{:,.1f} %'.format(utilidadsuelo2022*100/ utilidadtotal2022))
# Out:
# $18.852 M
# 25.5 %

# %%
ResumenporHorizonteyEmp_Suelo = Ventas_zona_producto_cultivo_Suelo_2022.groupby(['Zona_Ranking','Producto_']).agg({'Utilidad $M': 'sum'}).reset_index()
ResumenporHorizonteyEmp_Suelo_ = Ventas_zona_producto_cultivo_Suelo_2022.groupby(['Zona_Ranking','Producto_']).agg({'Utilidad $M': 'sum'})
ResumenporHorizonteyEmp_Suelo_df = pd.DataFrame(ResumenporHorizonteyEmp_Suelo_.unstack(level = 1))
ResumenporHorizonteyEmp_Suelo_df.plot.bar(stacked=True)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %%
Ventas_RM_Suelo_2022 = Ventas_zona_producto_cultivo_Suelo_2022.groupby(['RM/ REIQ_Ranking']).agg({'Utilidad $M': 'sum'})
Ventas_RM_Suelo_2022_sorted = Ventas_RM_Suelo_2022.sort_values(by=['Utilidad $M'],ascending=False)
Ventas_RM_Suelo_2022_sorted.head(10).style.format('${0:,.2f}').bar(color='lightgreen', vmin=0, subset=['Utilidad $M'])
# Out:
# <style  type="text/css" >
# #T_d558a_row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
#         }#T_d558a_row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 82.1%, transparent 82.1%);
#         }#T_d558a_row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 70.3%, transparent 70.3%);
#         }#T_d558a_row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 57.0%, transparent 57.0%);
#         }#T_d558a_row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 46.8%, transparent 46.8%);
#         }#T_d558a_row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 44.6%, transparent 44.6%);
#         }#T_d558a_row6_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 42.1%, transparent 42.1%);
#         }#T_d558a_row7_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 31.7%, transparent 31.7%);
#         }#T_d558a_row8_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 23.8%, transparent 23.8%);
#         }#T_d558a_row9_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 21.1%, transparent 21.1%);
#         }</style><table id="T_d558a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Utilidad $M</th>    </tr>    <tr>        <th class="index_name level0" >RM/ REIQ_Ranking</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d558a_level0_row0" class="row_heading level0 row0" >06 AACSA</th>
#                         <td id="T_d558a_row0_col0" class="data row0 col0" >$2.64</td>
#             </tr>
#             <tr>
#                         <th id="T_d558a_level0_row1" class="row_heading level0 row1" >10 Drokasa</th>
#                         <td id="T_d558a_row1_col0" class="data row1 col0" >$2.17</td>
#             </tr>
#             <tr>
#                         <th id="T_d558a_level0_row2" class="row_heading level0 row2" >02 JF</th>
#                         <td id="T_d558a_row2_col0" class="data row2 col0" >$1.86</td>
#             </tr>
#             <tr>
#                         <th id="T_d558a_level0_row3" class="row_heading level0 row3" >04 Dysea</th>
#                         <td id="T_d558a_row3_col0" class="data row3 col0" >$1.51</td>
#             </tr>
#             <tr>
#                         <th id="T_d558a_level0_row4" class="row_heading level0 row4" >09 GMT</th>
#                         <td id="T_d558a_row4_col0" class="data row4 col0" >$1.23</td>
#             </tr>
#             <tr>
#                         <th id="T_d558a_level0_row5" class="row_heading level0 row5" >03 Quinval</th>
#                         <td id="T_d558a_row5_col0" class="data row5 col0" >$1.18</td>
#             </tr>
#             <tr>
#                         <th id="T_d558a_level0_row6" class="row_heading level0 row6" >01 Ditecosa</th>
#                         <td id="T_d558a_row6_col0" class="data row6 col0" >$1.11</td>
#             </tr>
#             <tr>
#                         <th id="T_d558a_level0_row7" class="row_heading level0 row7" >05 GT</th>
#                         <td id="T_d558a_row7_col0" class="data row7 col0" >$0.84</td>
#             </tr>
#             <tr>
#                         <th id="T_d558a_level0_row8" class="row_heading level0 row8" >07 Fv</th>
#                         <td id="T_d558a_row8_col0" class="data row8 col0" >$0.63</td>
#             </tr>
#             <tr>
#                         <th id="T_d558a_level0_row9" class="row_heading level0 row9" >14 PromAgric</th>
#                         <td id="T_d558a_row9_col0" class="data row9 col0" >$0.56</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Bioestimulante, 2022

# %% [markdown]
# # Valor de Bioestimulante y lo que representa respecto a utilidad total

# %%
utilidadtotal2022 = Ventas_zona_producto_cultivo_2022['Utilidad'].sum()
utilidadbioest2022 = Ventas_zona_producto_cultivo_Bioest_2022['Utilidad'].sum()
print ('${:,.3f} M'.format(Ventas_zona_producto_cultivo_Bioest_2022['Utilidad'].sum()/1000000) )
print ('{:,.1f} %'.format(utilidadbioest2022*100/ utilidadtotal2022))
# Out:
# $12.030 M
# 16.3 %

# %%
ResumenporHorizonteyEmp_Bioest = Ventas_zona_producto_cultivo_Bioest_2022.groupby(['Zona_Ranking','Producto_']).agg({'Utilidad $M': 'sum'}).reset_index()
ResumenporHorizonteyEmp_Bioest_ = Ventas_zona_producto_cultivo_Bioest_2022.groupby(['Zona_Ranking','Producto_']).agg({'Utilidad $M': 'sum'})
ResumenporHorizonteyEmp_Bioest_df = pd.DataFrame(ResumenporHorizonteyEmp_Bioest_.unstack(level = 1))
ResumenporHorizonteyEmp_Bioest_df.plot.bar(stacked=True)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %%
Ventas_RM_Bioest_2022 = Ventas_zona_producto_cultivo_Bioest_2022.groupby(['RM/ REIQ_Ranking']).agg({'Utilidad $M': 'sum'})
Ventas_RM_Bioest_2022_sorted = Ventas_RM_Bioest_2022.sort_values(by=['Utilidad $M'],ascending=False)
Ventas_RM_Bioest_2022_sorted.head(10).style.format('${0:,.2f}').bar(color='lightgreen', vmin=0, subset=['Utilidad $M'])
# Out:
# <style  type="text/css" >
# #T_6ad70_row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
#         }#T_6ad70_row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 89.5%, transparent 89.5%);
#         }#T_6ad70_row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 68.3%, transparent 68.3%);
#         }#T_6ad70_row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 36.2%, transparent 36.2%);
#         }#T_6ad70_row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 30.1%, transparent 30.1%);
#         }#T_6ad70_row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 27.3%, transparent 27.3%);
#         }#T_6ad70_row6_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 26.7%, transparent 26.7%);
#         }#T_6ad70_row7_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 19.6%, transparent 19.6%);
#         }#T_6ad70_row8_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 15.1%, transparent 15.1%);
#         }#T_6ad70_row9_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 14.8%, transparent 14.8%);
#         }</style><table id="T_6ad70_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Utilidad $M</th>    </tr>    <tr>        <th class="index_name level0" >RM/ REIQ_Ranking</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6ad70_level0_row0" class="row_heading level0 row0" >08 Agrícola Piscis</th>
#                         <td id="T_6ad70_row0_col0" class="data row0 col0" >$2.29</td>
#             </tr>
#             <tr>
#                         <th id="T_6ad70_level0_row1" class="row_heading level0 row1" >01 Ditecosa</th>
#                         <td id="T_6ad70_row1_col0" class="data row1 col0" >$2.05</td>
#             </tr>
#             <tr>
#                         <th id="T_6ad70_level0_row2" class="row_heading level0 row2" >07 Fv</th>
#                         <td id="T_6ad70_row2_col0" class="data row2 col0" >$1.56</td>
#             </tr>
#             <tr>
#                         <th id="T_6ad70_level0_row3" class="row_heading level0 row3" >16 Txao</th>
#                         <td id="T_6ad70_row3_col0" class="data row3 col0" >$0.83</td>
#             </tr>
#             <tr>
#                         <th id="T_6ad70_level0_row4" class="row_heading level0 row4" >02 JF</th>
#                         <td id="T_6ad70_row4_col0" class="data row4 col0" >$0.69</td>
#             </tr>
#             <tr>
#                         <th id="T_6ad70_level0_row5" class="row_heading level0 row5" >03 Quinval</th>
#                         <td id="T_6ad70_row5_col0" class="data row5 col0" >$0.62</td>
#             </tr>
#             <tr>
#                         <th id="T_6ad70_level0_row6" class="row_heading level0 row6" >15 Ciba</th>
#                         <td id="T_6ad70_row6_col0" class="data row6 col0" >$0.61</td>
#             </tr>
#             <tr>
#                         <th id="T_6ad70_level0_row7" class="row_heading level0 row7" >12 Propios</th>
#                         <td id="T_6ad70_row7_col0" class="data row7 col0" >$0.45</td>
#             </tr>
#             <tr>
#                         <th id="T_6ad70_level0_row8" class="row_heading level0 row8" >19 Agrica</th>
#                         <td id="T_6ad70_row8_col0" class="data row8 col0" >$0.35</td>
#             </tr>
#             <tr>
#                         <th id="T_6ad70_level0_row9" class="row_heading level0 row9" >06 AACSA</th>
#                         <td id="T_6ad70_row9_col0" class="data row9 col0" >$0.34</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Coady 2022

# %% [markdown]
# # Valor de Coadyuvante y lo que  representa respecto a utilidad total

# %%
utilidadtotal2022 = Ventas_zona_producto_cultivo_2022['Utilidad'].sum()
utilidadcoady2022 = Ventas_zona_producto_cultivo_Coady_2022['Utilidad'].sum()
print ('${:,.3f} M'.format(Ventas_zona_producto_cultivo_Coady_2022['Utilidad'].sum()/1000000) )
print ('{:,.1f} %'.format(utilidadcoady2022*100/ utilidadtotal2022))
# Out:
# $10.581 M
# 14.3 %

# %%
ResumenporHorizonteyEmp_Coady = Ventas_zona_producto_cultivo_Coady_2022.groupby(['Zona_Ranking','Producto_']).agg({'Utilidad $M': 'sum'}).reset_index()
ResumenporHorizonteyEmp_Coady_ = Ventas_zona_producto_cultivo_Coady_2022.groupby(['Zona_Ranking','Producto_']).agg({'Utilidad $M': 'sum'})
ResumenporHorizonteyEmp_Coady_df = pd.DataFrame(ResumenporHorizonteyEmp_Coady_.unstack(level = 1))
ResumenporHorizonteyEmp_Coady_df.plot.bar(stacked=True)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %%
Ventas_zona_Coady_2022 = Ventas_zona_producto_cultivo_Coady_2022.groupby(['RM/ REIQ_Ranking']).agg({'Utilidad $M': 'sum'})
Ventas_zona_Coady_2022_sorted = Ventas_zona_Coady_2022.sort_values(by=['Utilidad $M'],ascending=False)
Ventas_zona_Coady_2022_sorted.head(10).style.format('${0:,.2f}').bar(color='lightgreen', vmin=0, subset=['Utilidad $M'])
# Out:
# <style  type="text/css" >
# #T_79eba_row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
#         }#T_79eba_row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 83.0%, transparent 83.0%);
#         }#T_79eba_row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 76.3%, transparent 76.3%);
#         }#T_79eba_row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 53.8%, transparent 53.8%);
#         }#T_79eba_row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 41.2%, transparent 41.2%);
#         }#T_79eba_row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 34.6%, transparent 34.6%);
#         }#T_79eba_row6_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 34.4%, transparent 34.4%);
#         }#T_79eba_row7_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 25.1%, transparent 25.1%);
#         }#T_79eba_row8_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 21.3%, transparent 21.3%);
#         }#T_79eba_row9_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 10.6%, transparent 10.6%);
#         }</style><table id="T_79eba_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Utilidad $M</th>    </tr>    <tr>        <th class="index_name level0" >RM/ REIQ_Ranking</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_79eba_level0_row0" class="row_heading level0 row0" >03 Quinval</th>
#                         <td id="T_79eba_row0_col0" class="data row0 col0" >$1.98</td>
#             </tr>
#             <tr>
#                         <th id="T_79eba_level0_row1" class="row_heading level0 row1" >02 JF</th>
#                         <td id="T_79eba_row1_col0" class="data row1 col0" >$1.64</td>
#             </tr>
#             <tr>
#                         <th id="T_79eba_level0_row2" class="row_heading level0 row2" >08 Agrícola Piscis</th>
#                         <td id="T_79eba_row2_col0" class="data row2 col0" >$1.51</td>
#             </tr>
#             <tr>
#                         <th id="T_79eba_level0_row3" class="row_heading level0 row3" >12 Propios</th>
#                         <td id="T_79eba_row3_col0" class="data row3 col0" >$1.06</td>
#             </tr>
#             <tr>
#                         <th id="T_79eba_level0_row4" class="row_heading level0 row4" >05 GT</th>
#                         <td id="T_79eba_row4_col0" class="data row4 col0" >$0.82</td>
#             </tr>
#             <tr>
#                         <th id="T_79eba_level0_row5" class="row_heading level0 row5" >07 Fv</th>
#                         <td id="T_79eba_row5_col0" class="data row5 col0" >$0.69</td>
#             </tr>
#             <tr>
#                         <th id="T_79eba_level0_row6" class="row_heading level0 row6" >06 AACSA</th>
#                         <td id="T_79eba_row6_col0" class="data row6 col0" >$0.68</td>
#             </tr>
#             <tr>
#                         <th id="T_79eba_level0_row7" class="row_heading level0 row7" >11 Empresas Melo</th>
#                         <td id="T_79eba_row7_col0" class="data row7 col0" >$0.50</td>
#             </tr>
#             <tr>
#                         <th id="T_79eba_level0_row8" class="row_heading level0 row8" >14 PromAgric</th>
#                         <td id="T_79eba_row8_col0" class="data row8 col0" >$0.42</td>
#             </tr>
#             <tr>
#                         <th id="T_79eba_level0_row9" class="row_heading level0 row9" >15 Ciba</th>
#                         <td id="T_79eba_row9_col0" class="data row9 col0" >$0.21</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Análisis Mx vs "Internacional"

# %%
RCZ_Mx = Ventas_zona_producto_cultivo_Mx_2022.groupby(['Administracion de la categoria','Zona_Ranking']).agg({'Utilidad $M': 'sum'}).reset_index()
RCZ_Mx_ = Ventas_zona_producto_cultivo_Mx_2022.groupby(['Administracion de la categoria','Zona_Ranking']).agg({'Utilidad $M': 'sum'})
RCZ_Mx_df = pd.DataFrame(RCZ_Mx_.unstack(level = 1))
RCZ_Mx_df.plot.bar(stacked=True)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %%
print ('${:,.3f} M'.format(RCZ_Mx['Utilidad $M'].sum()) )
# Out:
# $41.368 M

# %%
Ventas_RM_Mx_2022 = Ventas_zona_producto_cultivo_Mx_2022.groupby(['RM/ REIQ_Ranking']).agg({'Utilidad $M': 'sum'})
Ventas_RM_Mx_2022_sorted = Ventas_RM_Mx_2022.sort_values(by=['Utilidad $M'],ascending=False)
Ventas_RM_Mx_2022_sorted.head(10).style.format('${0:,.2f}').bar(color='lightgreen', vmin=0, subset=['Utilidad $M'])
# Out:
# <style  type="text/css" >
# #T_2a006_row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
#         }#T_2a006_row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 60.1%, transparent 60.1%);
#         }#T_2a006_row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 57.2%, transparent 57.2%);
#         }#T_2a006_row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 47.1%, transparent 47.1%);
#         }#T_2a006_row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 37.2%, transparent 37.2%);
#         }#T_2a006_row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 21.4%, transparent 21.4%);
#         }#T_2a006_row6_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 15.3%, transparent 15.3%);
#         }#T_2a006_row7_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 12.7%, transparent 12.7%);
#         }#T_2a006_row8_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 12.3%, transparent 12.3%);
#         }#T_2a006_row9_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 9.1%, transparent 9.1%);
#         }</style><table id="T_2a006_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Utilidad $M</th>    </tr>    <tr>        <th class="index_name level0" >RM/ REIQ_Ranking</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2a006_level0_row0" class="row_heading level0 row0" >01 Ditecosa</th>
#                         <td id="T_2a006_row0_col0" class="data row0 col0" >$10.55</td>
#             </tr>
#             <tr>
#                         <th id="T_2a006_level0_row1" class="row_heading level0 row1" >02 JF</th>
#                         <td id="T_2a006_row1_col0" class="data row1 col0" >$6.34</td>
#             </tr>
#             <tr>
#                         <th id="T_2a006_level0_row2" class="row_heading level0 row2" >03 Quinval</th>
#                         <td id="T_2a006_row2_col0" class="data row2 col0" >$6.04</td>
#             </tr>
#             <tr>
#                         <th id="T_2a006_level0_row3" class="row_heading level0 row3" >06 AACSA</th>
#                         <td id="T_2a006_row3_col0" class="data row3 col0" >$4.97</td>
#             </tr>
#             <tr>
#                         <th id="T_2a006_level0_row4" class="row_heading level0 row4" >07 Fv</th>
#                         <td id="T_2a006_row4_col0" class="data row4 col0" >$3.92</td>
#             </tr>
#             <tr>
#                         <th id="T_2a006_level0_row5" class="row_heading level0 row5" >15 Ciba</th>
#                         <td id="T_2a006_row5_col0" class="data row5 col0" >$2.25</td>
#             </tr>
#             <tr>
#                         <th id="T_2a006_level0_row6" class="row_heading level0 row6" >04 Dysea</th>
#                         <td id="T_2a006_row6_col0" class="data row6 col0" >$1.61</td>
#             </tr>
#             <tr>
#                         <th id="T_2a006_level0_row7" class="row_heading level0 row7" >13 Hormonas</th>
#                         <td id="T_2a006_row7_col0" class="data row7 col0" >$1.34</td>
#             </tr>
#             <tr>
#                         <th id="T_2a006_level0_row8" class="row_heading level0 row8" >14 PromAgric</th>
#                         <td id="T_2a006_row8_col0" class="data row8 col0" >$1.30</td>
#             </tr>
#             <tr>
#                         <th id="T_2a006_level0_row9" class="row_heading level0 row9" >39 Serco Verde</th>
#                         <td id="T_2a006_row9_col0" class="data row9 col0" >$0.96</td>
#             </tr>
#     </tbody></table>

# %%
print ('${:,.3f} M'.format(Ventas_RM_Mx_2022['Utilidad $M'].head(10).sum()) )
# Out:
# $39.067 M

# %%
RCZ_noesMx = Ventas_zona_producto_cultivo_noesMx_2022.groupby(['Administracion de la categoria','Zona_Ranking']).agg({'Utilidad $M': 'sum'}).reset_index()
RCZ_noesMx_ = Ventas_zona_producto_cultivo_noesMx_2022.groupby(['Administracion de la categoria','Zona_Ranking']).agg({'Utilidad $M': 'sum'})
RCZ_noesMx_df = pd.DataFrame(RCZ_noesMx_.unstack(level = 1))
RCZ_noesMx_df.plot.bar(stacked=True)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %%
print ('${:,.3f} M'.format(RCZ_noesMx['Utilidad $M'].sum()) )
# Out:
# $32.578 M

# %%
Ventas_RM_noesMx_2022 = Ventas_zona_producto_cultivo_noesMx_2022.groupby(['RM/ REIQ_Ranking']).agg({'Utilidad $M': 'sum'})
Ventas_RM_noesMx_2022_sorted = Ventas_RM_noesMx_2022.sort_values(by=['Utilidad $M'],ascending=False)
Ventas_RM_noesMx_2022_sorted.head(10).style.format('${0:,.2f}').bar(color='lightgreen', vmin=0, subset=['Utilidad $M'])
# Out:
# <style  type="text/css" >
# #T_acff7_row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
#         }#T_acff7_row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 61.4%, transparent 61.4%);
#         }#T_acff7_row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 54.0%, transparent 54.0%);
#         }#T_acff7_row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 45.6%, transparent 45.6%);
#         }#T_acff7_row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 43.9%, transparent 43.9%);
#         }#T_acff7_row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 33.4%, transparent 33.4%);
#         }#T_acff7_row6_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 19.3%, transparent 19.3%);
#         }#T_acff7_row7_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 16.6%, transparent 16.6%);
#         }#T_acff7_row8_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 14.7%, transparent 14.7%);
#         }#T_acff7_row9_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 11.2%, transparent 11.2%);
#         }</style><table id="T_acff7_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Utilidad $M</th>    </tr>    <tr>        <th class="index_name level0" >RM/ REIQ_Ranking</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_acff7_level0_row0" class="row_heading level0 row0" >10 Drokasa</th>
#                         <td id="T_acff7_row0_col0" class="data row0 col0" >$7.42</td>
#             </tr>
#             <tr>
#                         <th id="T_acff7_level0_row1" class="row_heading level0 row1" >08 Agrícola Piscis</th>
#                         <td id="T_acff7_row1_col0" class="data row1 col0" >$4.55</td>
#             </tr>
#             <tr>
#                         <th id="T_acff7_level0_row2" class="row_heading level0 row2" >05 GT</th>
#                         <td id="T_acff7_row2_col0" class="data row2 col0" >$4.00</td>
#             </tr>
#             <tr>
#                         <th id="T_acff7_level0_row3" class="row_heading level0 row3" >12 Propios</th>
#                         <td id="T_acff7_row3_col0" class="data row3 col0" >$3.38</td>
#             </tr>
#             <tr>
#                         <th id="T_acff7_level0_row4" class="row_heading level0 row4" >11 Empresas Melo</th>
#                         <td id="T_acff7_row4_col0" class="data row4 col0" >$3.26</td>
#             </tr>
#             <tr>
#                         <th id="T_acff7_level0_row5" class="row_heading level0 row5" >16 Txao</th>
#                         <td id="T_acff7_row5_col0" class="data row5 col0" >$2.48</td>
#             </tr>
#             <tr>
#                         <th id="T_acff7_level0_row6" class="row_heading level0 row6" >05 HN</th>
#                         <td id="T_acff7_row6_col0" class="data row6 col0" >$1.43</td>
#             </tr>
#             <tr>
#                         <th id="T_acff7_level0_row7" class="row_heading level0 row7" >09 GMT</th>
#                         <td id="T_acff7_row7_col0" class="data row7 col0" >$1.23</td>
#             </tr>
#             <tr>
#                         <th id="T_acff7_level0_row8" class="row_heading level0 row8" >05 NC</th>
#                         <td id="T_acff7_row8_col0" class="data row8 col0" >$1.09</td>
#             </tr>
#             <tr>
#                         <th id="T_acff7_level0_row9" class="row_heading level0 row9" >19 Agrica</th>
#                         <td id="T_acff7_row9_col0" class="data row9 col0" >$0.83</td>
#             </tr>
#     </tbody></table>

# %%
print ('${:,.3f} M'.format(Ventas_RM_noesMx_2022['Utilidad $M'].head(10).sum()) )
# Out:
# $29.557 M
